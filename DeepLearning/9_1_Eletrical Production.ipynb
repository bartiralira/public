# %% [markdown]
# ***Participantes (RM - NOME):***<br>
# Vitor Luiz Carvalhal - 337129<br>
# Ricardo Fabbro Antonelli - 339505<br>
# Bartira Lira Lafiandre - 340177<br>
# Tiago Batista Pessoa - 339575<br>

# %% [markdown]
# ## Exercício 9.1
# ---
# Utilizando o dataset Eletrical_Production.csv (disponível no repositório da disciplina) faça uma previsão de série temporal utilizando LSTM para
# prever os últimos 20% de dias do dataset (conjunto de treino)<br>
# Instruções Gerais:<br>
# >É permitido usar outras abordagens e arquiteturas de LSTM;<br>
# >Não é permitido o uso de modelos pré treinados<br>
# >O Aluno pode escolher a janela de tempo para compor o conjunto de
# treinamento.

# %% [markdown]
# ## 0. Bibbliotecas e afins

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math

from keras.models import Sequential,load_model
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import mean_squared_error

import plotly.express as px

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# monta google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Analisando os dados

# %%
np.random.seed(7)

#Carrega o dataset
dataframe = read_csv("https://telescopeinstorage.blob.core.windows.net/datasets/Eletrical_Production.csv", usecols=[1], engine='python')
dataframe.head(150)
# Out:
#      IPG2211A2N
# 0        3.3842
# 1        3.4100
# 2        3.4875
# 3        3.5133
# 4        3.5133
# ..          ...
# 145     10.2817
# 146     10.2817
# 147     10.2559
# 148     10.0492
# 149     10.1784
#
# [150 rows x 1 columns]

# %%
dataframe.shape
# Out:
# (964, 1)

# %%
X = dataframe.values
X = X.astype('float32')

# %%
plt.figure(figsize=(10,8))
plt.plot(dataframe)

# %% [markdown]
# ## 2. Preparando os dados para o modelo

# %%
#Selecionei uma faixa de tempo a partir de 500. Isso evitará termo enviesamento pelo historico muito antigo.
X = X[350:len(X),:]

# %%
plt.figure(figsize=(10,8))
plt.plot(X)

# %%
#Normaliza o dataset
scaler = MinMaxScaler(feature_range=(0, 1))

#scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
#Separando em conjunto de treino e de teste. 80% para treino e 20% para teste
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size

train = X[0:train_size,:]
test =  X[train_size:len(X),:]

print(train.shape)
print(test.shape)
# Out:
# (491, 1)
# (123, 1)

# %%
#checando como ficou o conjunto de treino
plt.plot(train)

# %%
#checando como ficou o conjunto de teste
plt.plot(test)

# %%
# quantidade de atrasos
look_back = 3

X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

#gerando conjunto de validacao
(X_train, x_valid) = X_train[100:], X_train[:100]
(y_train, y_valid) = y_train[100:], y_train[:100]

X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
x_valid = np.reshape(x_valid, (x_valid.shape[0], x_valid.shape[1], 1))

# %%
print(X_train.shape, 'train samples')
print(X_test.shape, 'test samples')
print(x_valid.shape, 'validation samples')
# Out:
# (487, 3, 1) train samples
# (119, 3, 1) test samples
# (100, 3, 1) validation samples

# %%
X_train.shape
# Out:
# (487, 3, 1)

# %% [markdown]
# ## 3. Modelagem

# %%
# Cria e treina a rede LSTM
model = Sequential()
model.add(LSTM(8, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='Adamax', metrics = ['mae'])

# %% [markdown]
# >>Vamos adicionar model checkpoint para guardar a melhor predicao pois treinamento em 100 epocas

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath='/content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5', verbose=1,  save_best_only=True, monitor='val_mae') #

hist = model.fit(X_train, y_train, batch_size=1, epochs=100,validation_data=(x_valid, y_valid), callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Epoch 1/100
# 487/487 [==============================] - 19s 4ms/step - loss: 0.0425 - mae: 0.1620 - val_loss: 0.0102 - val_mae: 0.0953
#
# Epoch 00001: val_mae improved from inf to 0.09527, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 2/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0119 - mae: 0.0888 - val_loss: 0.0058 - val_mae: 0.0695
#
# Epoch 00002: val_mae improved from 0.09527 to 0.06951, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 3/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0078 - mae: 0.0721 - val_loss: 0.0027 - val_mae: 0.0452
#
# Epoch 00003: val_mae improved from 0.06951 to 0.04520, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 4/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0066 - mae: 0.0685 - val_loss: 0.0022 - val_mae: 0.0396
#
# Epoch 00004: val_mae improved from 0.04520 to 0.03965, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 5/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0063 - mae: 0.0656 - val_loss: 0.0016 - val_mae: 0.0333
#
# Epoch 00005: val_mae improved from 0.03965 to 0.03333, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 6/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0067 - mae: 0.0682 - val_loss: 0.0011 - val_mae: 0.0273
#
# Epoch 00006: val_mae improved from 0.03333 to 0.02728, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 7/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0069 - mae: 0.0659 - val_loss: 0.0019 - val_mae: 0.0359
#
# Epoch 00007: val_mae did not improve from 0.02728
# Epoch 8/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0066 - mae: 0.0665 - val_loss: 0.0014 - val_mae: 0.0311
#
# Epoch 00008: val_mae did not improve from 0.02728
# Epoch 9/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0075 - mae: 0.0705 - val_loss: 0.0020 - val_mae: 0.0376
#
# Epoch 00009: val_mae did not improve from 0.02728
# Epoch 10/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0068 - mae: 0.0675 - val_loss: 0.0018 - val_mae: 0.0356
#
# Epoch 00010: val_mae did not improve from 0.02728
# Epoch 11/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0065 - mae: 0.0659 - val_loss: 0.0012 - val_mae: 0.0286
#
# Epoch 00011: val_mae did not improve from 0.02728
# Epoch 12/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0059 - mae: 0.0622 - val_loss: 0.0017 - val_mae: 0.0336
#
# Epoch 00012: val_mae did not improve from 0.02728
# Epoch 13/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0067 - mae: 0.0686 - val_loss: 0.0014 - val_mae: 0.0305
#
# Epoch 00013: val_mae did not improve from 0.02728
# Epoch 14/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0060 - mae: 0.0628 - val_loss: 0.0013 - val_mae: 0.0290
#
# Epoch 00014: val_mae did not improve from 0.02728
# Epoch 15/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0065 - mae: 0.0648 - val_loss: 0.0011 - val_mae: 0.0265
#
# Epoch 00015: val_mae improved from 0.02728 to 0.02653, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 16/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0067 - mae: 0.0662 - val_loss: 0.0023 - val_mae: 0.0408
#
# Epoch 00016: val_mae did not improve from 0.02653
# Epoch 17/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0067 - mae: 0.0666 - val_loss: 0.0014 - val_mae: 0.0309
#
# Epoch 00017: val_mae did not improve from 0.02653
# Epoch 18/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0063 - mae: 0.0657 - val_loss: 0.0012 - val_mae: 0.0282
#
# Epoch 00018: val_mae did not improve from 0.02653
# Epoch 19/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0060 - mae: 0.0622 - val_loss: 0.0014 - val_mae: 0.0305
#
# Epoch 00019: val_mae did not improve from 0.02653
# Epoch 20/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0066 - mae: 0.0668 - val_loss: 0.0012 - val_mae: 0.0285
#
# Epoch 00020: val_mae did not improve from 0.02653
# Epoch 21/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0062 - mae: 0.0629 - val_loss: 0.0011 - val_mae: 0.0274
#
# Epoch 00021: val_mae did not improve from 0.02653
# Epoch 22/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0056 - mae: 0.0612 - val_loss: 0.0011 - val_mae: 0.0271
#
# Epoch 00022: val_mae did not improve from 0.02653
# Epoch 23/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0053 - mae: 0.0576 - val_loss: 0.0012 - val_mae: 0.0281
#
# Epoch 00023: val_mae did not improve from 0.02653
# Epoch 24/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0059 - mae: 0.0617 - val_loss: 0.0013 - val_mae: 0.0289
#
# Epoch 00024: val_mae did not improve from 0.02653
# Epoch 25/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0056 - mae: 0.0610 - val_loss: 0.0018 - val_mae: 0.0348
#
# Epoch 00025: val_mae did not improve from 0.02653
# Epoch 26/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0058 - mae: 0.0624 - val_loss: 0.0011 - val_mae: 0.0261
#
# Epoch 00026: val_mae improved from 0.02653 to 0.02610, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 27/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0050 - mae: 0.0571 - val_loss: 0.0011 - val_mae: 0.0272
#
# Epoch 00027: val_mae did not improve from 0.02610
# Epoch 28/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0052 - mae: 0.0572 - val_loss: 0.0012 - val_mae: 0.0281
#
# Epoch 00028: val_mae did not improve from 0.02610
# Epoch 29/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0056 - mae: 0.0610 - val_loss: 0.0012 - val_mae: 0.0279
#
# Epoch 00029: val_mae did not improve from 0.02610
# Epoch 30/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0053 - mae: 0.0588 - val_loss: 9.6602e-04 - val_mae: 0.0249
#
# Epoch 00030: val_mae improved from 0.02610 to 0.02490, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 31/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0050 - mae: 0.0566 - val_loss: 0.0012 - val_mae: 0.0281
#
# Epoch 00031: val_mae did not improve from 0.02490
# Epoch 32/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0053 - mae: 0.0591 - val_loss: 0.0011 - val_mae: 0.0262
#
# Epoch 00032: val_mae did not improve from 0.02490
# Epoch 33/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0051 - mae: 0.0574 - val_loss: 0.0012 - val_mae: 0.0285
#
# Epoch 00033: val_mae did not improve from 0.02490
# Epoch 34/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0050 - mae: 0.0560 - val_loss: 0.0011 - val_mae: 0.0270
#
# Epoch 00034: val_mae did not improve from 0.02490
# Epoch 35/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0052 - mae: 0.0590 - val_loss: 0.0012 - val_mae: 0.0283
#
# Epoch 00035: val_mae did not improve from 0.02490
# Epoch 36/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0047 - mae: 0.0550 - val_loss: 9.9411e-04 - val_mae: 0.0256
#
# Epoch 00036: val_mae did not improve from 0.02490
# Epoch 37/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0051 - mae: 0.0584 - val_loss: 0.0013 - val_mae: 0.0296
#
# Epoch 00037: val_mae did not improve from 0.02490
# Epoch 38/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0049 - mae: 0.0568 - val_loss: 0.0011 - val_mae: 0.0274
#
# Epoch 00038: val_mae did not improve from 0.02490
# Epoch 39/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0046 - mae: 0.0542 - val_loss: 0.0011 - val_mae: 0.0273
#
# Epoch 00039: val_mae did not improve from 0.02490
# Epoch 40/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0045 - mae: 0.0554 - val_loss: 9.3648e-04 - val_mae: 0.0251
#
# Epoch 00040: val_mae did not improve from 0.02490
# Epoch 41/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0043 - mae: 0.0528 - val_loss: 9.8741e-04 - val_mae: 0.0256
#
# Epoch 00041: val_mae did not improve from 0.02490
# Epoch 42/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0041 - mae: 0.0521 - val_loss: 8.4678e-04 - val_mae: 0.0241
#
# Epoch 00042: val_mae improved from 0.02490 to 0.02406, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 43/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0037 - mae: 0.0502 - val_loss: 0.0012 - val_mae: 0.0277
#
# Epoch 00043: val_mae did not improve from 0.02406
# Epoch 44/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0043 - mae: 0.0529 - val_loss: 9.1597e-04 - val_mae: 0.0250
#
# Epoch 00044: val_mae did not improve from 0.02406
# Epoch 45/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0042 - mae: 0.0530 - val_loss: 8.6271e-04 - val_mae: 0.0244
#
# Epoch 00045: val_mae did not improve from 0.02406
# Epoch 46/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0040 - mae: 0.0515 - val_loss: 9.2851e-04 - val_mae: 0.0251
#
# Epoch 00046: val_mae did not improve from 0.02406
# Epoch 47/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0041 - mae: 0.0530 - val_loss: 8.2658e-04 - val_mae: 0.0241
#
# Epoch 00047: val_mae did not improve from 0.02406
# Epoch 48/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0040 - mae: 0.0518 - val_loss: 7.8659e-04 - val_mae: 0.0235
#
# Epoch 00048: val_mae improved from 0.02406 to 0.02354, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 49/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0038 - mae: 0.0513 - val_loss: 7.8311e-04 - val_mae: 0.0236
#
# Epoch 00049: val_mae did not improve from 0.02354
# Epoch 50/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0034 - mae: 0.0475 - val_loss: 7.6795e-04 - val_mae: 0.0232
#
# Epoch 00050: val_mae improved from 0.02354 to 0.02317, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 51/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0040 - mae: 0.0521 - val_loss: 8.4599e-04 - val_mae: 0.0242
#
# Epoch 00051: val_mae did not improve from 0.02317
# Epoch 52/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0039 - mae: 0.0494 - val_loss: 7.6051e-04 - val_mae: 0.0233
#
# Epoch 00052: val_mae did not improve from 0.02317
# Epoch 53/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0033 - mae: 0.0473 - val_loss: 7.5913e-04 - val_mae: 0.0233
#
# Epoch 00053: val_mae did not improve from 0.02317
# Epoch 54/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0035 - mae: 0.0484 - val_loss: 7.3003e-04 - val_mae: 0.0230
#
# Epoch 00054: val_mae improved from 0.02317 to 0.02295, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 55/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0032 - mae: 0.0465 - val_loss: 7.9897e-04 - val_mae: 0.0236
#
# Epoch 00055: val_mae did not improve from 0.02295
# Epoch 56/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0030 - mae: 0.0452 - val_loss: 7.0299e-04 - val_mae: 0.0226
#
# Epoch 00056: val_mae improved from 0.02295 to 0.02261, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 57/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0032 - mae: 0.0469 - val_loss: 7.2126e-04 - val_mae: 0.0227
#
# Epoch 00057: val_mae did not improve from 0.02261
# Epoch 58/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0032 - mae: 0.0463 - val_loss: 8.1970e-04 - val_mae: 0.0233
#
# Epoch 00058: val_mae did not improve from 0.02261
# Epoch 59/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0030 - mae: 0.0452 - val_loss: 6.3928e-04 - val_mae: 0.0218
#
# Epoch 00059: val_mae improved from 0.02261 to 0.02176, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 60/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0028 - mae: 0.0430 - val_loss: 6.7902e-04 - val_mae: 0.0217
#
# Epoch 00060: val_mae improved from 0.02176 to 0.02166, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 61/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0029 - mae: 0.0428 - val_loss: 5.7739e-04 - val_mae: 0.0208
#
# Epoch 00061: val_mae improved from 0.02166 to 0.02076, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 62/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0025 - mae: 0.0403 - val_loss: 5.9138e-04 - val_mae: 0.0206
#
# Epoch 00062: val_mae improved from 0.02076 to 0.02057, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 63/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0024 - mae: 0.0402 - val_loss: 6.4724e-04 - val_mae: 0.0206
#
# Epoch 00063: val_mae did not improve from 0.02057
# Epoch 64/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0024 - mae: 0.0392 - val_loss: 6.0618e-04 - val_mae: 0.0200
#
# Epoch 00064: val_mae improved from 0.02057 to 0.02003, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 65/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0023 - mae: 0.0387 - val_loss: 7.2854e-04 - val_mae: 0.0216
#
# Epoch 00065: val_mae did not improve from 0.02003
# Epoch 66/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0023 - mae: 0.0378 - val_loss: 4.8956e-04 - val_mae: 0.0188
#
# Epoch 00066: val_mae improved from 0.02003 to 0.01885, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 67/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0024 - mae: 0.0384 - val_loss: 4.6322e-04 - val_mae: 0.0184
#
# Epoch 00067: val_mae improved from 0.01885 to 0.01840, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 68/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0022 - mae: 0.0362 - val_loss: 6.5441e-04 - val_mae: 0.0207
#
# Epoch 00068: val_mae did not improve from 0.01840
# Epoch 69/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0359 - val_loss: 4.9262e-04 - val_mae: 0.0182
#
# Epoch 00069: val_mae improved from 0.01840 to 0.01820, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 70/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0023 - mae: 0.0364 - val_loss: 4.5420e-04 - val_mae: 0.0177
#
# Epoch 00070: val_mae improved from 0.01820 to 0.01769, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 71/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0356 - val_loss: 5.5672e-04 - val_mae: 0.0191
#
# Epoch 00071: val_mae did not improve from 0.01769
# Epoch 72/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0019 - mae: 0.0335 - val_loss: 4.2393e-04 - val_mae: 0.0173
#
# Epoch 00072: val_mae improved from 0.01769 to 0.01734, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 73/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0358 - val_loss: 6.6200e-04 - val_mae: 0.0209
#
# Epoch 00073: val_mae did not improve from 0.01734
# Epoch 74/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0363 - val_loss: 6.4522e-04 - val_mae: 0.0207
#
# Epoch 00074: val_mae did not improve from 0.01734
# Epoch 75/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0024 - mae: 0.0368 - val_loss: 4.4907e-04 - val_mae: 0.0173
#
# Epoch 00075: val_mae improved from 0.01734 to 0.01729, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 76/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0020 - mae: 0.0346 - val_loss: 5.5195e-04 - val_mae: 0.0191
#
# Epoch 00076: val_mae did not improve from 0.01729
# Epoch 77/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0022 - mae: 0.0356 - val_loss: 4.5390e-04 - val_mae: 0.0173
#
# Epoch 00077: val_mae did not improve from 0.01729
# Epoch 78/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0020 - mae: 0.0341 - val_loss: 4.4135e-04 - val_mae: 0.0171
#
# Epoch 00078: val_mae improved from 0.01729 to 0.01709, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 79/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0342 - val_loss: 4.6680e-04 - val_mae: 0.0175
#
# Epoch 00079: val_mae did not improve from 0.01709
# Epoch 80/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0022 - mae: 0.0348 - val_loss: 4.0560e-04 - val_mae: 0.0166
#
# Epoch 00080: val_mae improved from 0.01709 to 0.01657, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 81/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0020 - mae: 0.0345 - val_loss: 4.0740e-04 - val_mae: 0.0166
#
# Epoch 00081: val_mae improved from 0.01657 to 0.01656, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 82/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0338 - val_loss: 4.1149e-04 - val_mae: 0.0166
#
# Epoch 00082: val_mae improved from 0.01656 to 0.01655, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 83/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0019 - mae: 0.0336 - val_loss: 4.9164e-04 - val_mae: 0.0179
#
# Epoch 00083: val_mae did not improve from 0.01655
# Epoch 84/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0020 - mae: 0.0332 - val_loss: 4.6606e-04 - val_mae: 0.0174
#
# Epoch 00084: val_mae did not improve from 0.01655
# Epoch 85/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0022 - mae: 0.0357 - val_loss: 4.9212e-04 - val_mae: 0.0180
#
# Epoch 00085: val_mae did not improve from 0.01655
# Epoch 86/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0343 - val_loss: 3.9304e-04 - val_mae: 0.0162
#
# Epoch 00086: val_mae improved from 0.01655 to 0.01619, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 87/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0348 - val_loss: 3.9365e-04 - val_mae: 0.0162
#
# Epoch 00087: val_mae improved from 0.01619 to 0.01616, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 88/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0345 - val_loss: 4.8821e-04 - val_mae: 0.0179
#
# Epoch 00088: val_mae did not improve from 0.01616
# Epoch 89/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0021 - mae: 0.0345 - val_loss: 4.0766e-04 - val_mae: 0.0164
#
# Epoch 00089: val_mae did not improve from 0.01616
# Epoch 90/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0024 - mae: 0.0361 - val_loss: 4.4952e-04 - val_mae: 0.0171
#
# Epoch 00090: val_mae did not improve from 0.01616
# Epoch 91/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0020 - mae: 0.0341 - val_loss: 4.1883e-04 - val_mae: 0.0165
#
# Epoch 00091: val_mae did not improve from 0.01616
# Epoch 92/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0018 - mae: 0.0316 - val_loss: 3.7705e-04 - val_mae: 0.0159
#
# Epoch 00092: val_mae improved from 0.01616 to 0.01594, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5
# Epoch 93/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0018 - mae: 0.0321 - val_loss: 4.0300e-04 - val_mae: 0.0162
#
# Epoch 00093: val_mae did not improve from 0.01594
# Epoch 94/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0020 - mae: 0.0339 - val_loss: 4.0636e-04 - val_mae: 0.0163
#
# Epoch 00094: val_mae did not improve from 0.01594
# Epoch 95/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0018 - mae: 0.0317 - val_loss: 4.4375e-04 - val_mae: 0.0170
#
# Epoch 00095: val_mae did not improve from 0.01594
# Epoch 96/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0020 - mae: 0.0323 - val_loss: 5.0431e-04 - val_mae: 0.0181
#
# Epoch 00096: val_mae did not improve from 0.01594
# Epoch 97/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0018 - mae: 0.0310 - val_loss: 4.5117e-04 - val_mae: 0.0171
#
# Epoch 00097: val_mae did not improve from 0.01594
# Epoch 98/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0020 - mae: 0.0335 - val_loss: 4.2726e-04 - val_mae: 0.0166
#
# Epoch 00098: val_mae did not improve from 0.01594
# Epoch 99/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0019 - mae: 0.0323 - val_loss: 4.1013e-04 - val_mae: 0.0163
#
# Epoch 00099: val_mae did not improve from 0.01594
# Epoch 100/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.0022 - mae: 0.0336 - val_loss: 3.6905e-04 - val_mae: 0.0158
#
# Epoch 00100: val_mae improved from 0.01594 to 0.01581, saving model to /content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5

# %% [markdown]
# ## 4. Avaliação do modelo e aplicação no conjunto de teste

# %%
plt.figure(1)
plt.plot(hist.history['mae'])
plt.plot(hist.history['val_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#carrega o melhor modelo
model = load_model("/content/drive/MyDrive/Dataset/modeloPredicaoEletrica.hdf5")

# %%
#Acuracidade do conjunto de treino
score = model.evaluate(X_train, y_train, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.03397773951292038

# %%
# Realiza as Predições no conjunto de treino e de teste
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# %%
# Faz a transformação inversa das predições
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 4.29 RMSE
# Test Score: 7.48 RMSE

# %%
# Prepara o vetor para plotagem do conjunto de treinamento
trainPredictPlot = np.empty_like(X)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back-1:len(trainPredict)+look_back-1, :] = trainPredict

# %%
# Prepara o vetor para plotagem do conjunto das predições
testPredictPlot = np.empty_like(X)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(X)-2, :] = testPredict

# %%
# Plota o dataset, as predições sobre o conjunto de treinamento e teste
plt.figure(figsize=(20,8))
plt.plot(scaler.inverse_transform(X))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
